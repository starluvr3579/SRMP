# %% [markdown]
# <a href="https://colab.research.google.com/github/starluvr3579/SRMP/blob/main/Oct17_DDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/starluvr3579/SRMP.git
# Out:
# Cloning into 'SRMP'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (28/28), done.
# remote: Compressing objects: 100% (26/26), done.
# remote: Total 28 (delta 9), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (28/28), 257.91 KiB | 5.16 MiB/s, done.
# Resolving deltas: 100% (9/9), done.

# %%
import pandas as pd

# %%
df=pd.read_csv('KIC_1569863.txt')

# %%
list(df.columns)
# Out:
# ['time', 'flux']

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df['time'], df['flux'], '*')
plt.xlabel('time[days]')
plt.ylabel('flux')
# Out:
# Text(0, 0.5, 'flux')
