# %% [markdown]
# <a href="https://colab.research.google.com/github/starluvr3579/SRMP/blob/main/Oct24_DDM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/starluvr3579/SRMP.git
# Out:
# Cloning into 'SRMP'...
# remote: Enumerating objects: 31, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (29/29), done.
# remote: Total 31 (delta 10), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (31/31), 283.54 KiB | 6.03 MiB/s, done.
# Resolving deltas: 100% (10/10), done.

# %%
import pandas as pd

# %%
df=pd.read_csv('KIC_1026474_EB.txt')

# %%
list(df.columns)
# Out:
# ['time', 'flux']

# %%
import matplotlib.pyplot as plt
plt.plot(df['time'], df['flux'])
plt.xlabel('time[days]')
plt.ylabel('flux')
plt.ylim(10000,10600)
plt.xlim(820,840)
# Out:
# (820.0, 840.0)

# %%
df=pd.read_csv('GP_gyro_update_MCMC_Rocut.csv')

# %%
list(df.columns)
# Out:
# ['Unnamed: 0',
#  'Prot',
#  'bp_rp',
#  'abs_G',
#  'Prot_log',
#  'teff_calc',
#  'source_id',
#  'kepid',
#  'gyroage',
#  'gyroage_m',
#  'gyroage_p',
#  'τc',
#  'Ro']

# %%
from operator import invert
import matplotlib.pyplot as plt
plt.plot(df['teff_calc'], df['Prot'],'.')
plt.xlabel('teff')
plt.ylabel('Prot')
plt.gca().invert_xaxis()
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
plt.plot(df['gyroage'], df['Prot'] ,'.')
plt.ylabel('period')
plt.xlabel('age')
plt.yscale('log')
plt.xscale('log')
